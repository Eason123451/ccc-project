# %%
from get_tweets_sentiment_url import plot_combined_sentiment_and_tweets
from get_viccrime_sentiment_url import plot_crime_sentiment_url
from get_interesting_day_url import plot_sentiment_distribution, sample_crime_busiest_tweets, sample_crime_quietest_tweets

# %% [markdown]
# ### Compare Average Sentiment Every Day with The Number of Tweets Every Day

# %%
plot_combined_sentiment_and_tweets()

# %%
plot_sentiment_distribution()

# %% [markdown]
# ### Correlation between Crime Reports and Daily Average Sentiment

# %%
plot_crime_sentiment_url()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ### Sample Crime Related Tweet for The Two Interesting Days

# %%
sample_crime_busiest_tweets()
# Out:
#     <style>
#         table, th, td {
#             border: 1px solid black;
#             border-collapse: collapse;
#         }
#         th, td {
#             padding: 10px;
#             text-align: left;
#             vertical-align: top;
#         }
#         td {
#             max-width: 500px;  /* Adjust the width of the cells */
#             word-wrap: break-word;  /* Ensures that words wrap and text does not overflow */
#         }
#     </style>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Sentiment</th>
#       <th>Text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>-0.180</td>
#       <td>The last time I felt to terrified of fellow Aussies was when I got multiple daily death threats for stating that refugees who come by sea are not criminals, now morons are trying to force pple to have a deadly poison jab as if they are buying brands of shoes</td>
#     </tr>
#     <tr>
#       <td>-0.280</td>
#       <td>It’s just ridiculous to allow criminals and with a sick mental person at that. What was and is s thinking off ! Only in a!</td>
#     </tr>
#     <tr>
#       <td>-0.128</td>
#       <td>That’s sad to hear from you s, but I’ll take your advice on voting them OUT, people pushing back against draconian laws and the destroying of business and the family and you’re against that, that’ll do me ‍️‍️‍️</td>
#     </tr>
#     <tr>
#       <td>-0.115</td>
#       <td>Wasted 3 years and no action on promised tabdeeli, what will he say, cosmetic surgery, corruption, forced wedding, what else has I been doing. Where are 200 billion dollars echoed by d? What happened to drug bust evidence by i on that pmln member?</td>
#     </tr>
#     <tr>
#       <td>-0.029</td>
#       <td>I saw the video ..someone completely blocked the footage at the exact moment so it's inconclusive to me. He did get taken by police who were right next to him.</td>
#     </tr>
#   </tbody>
# </table>

# %%
sample_crime_quietest_tweets()
# Out:
#     <style>
#         table, th, td {
#             border: 1px solid black;
#             border-collapse: collapse;
#         }
#         th, td {
#             padding: 10px;
#             text-align: left;
#             vertical-align: top;
#         }
#         td {
#             max-width: 500px;  /* Adjust the width of the cells */
#             word-wrap: break-word;  /* Ensures that words wrap and text does not overflow */
#         }
#     </style>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Sentiment</th>
#       <th>Text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>-0.094</td>
#       <td>By the way, those other methods she mentioned. Those ones actually catch fraud, requiring ID doesn't. Its the having your name marked off that prevents getting a second ballot or being able to catch someone voting twice by going to different polling stations. Not IDs.</td>
#     </tr>
#     <tr>
#       <td>-0.105</td>
#       <td>Join me in supporting the Fight for Voluntary Assisted Dying Laws in W in 2021</td>
#     </tr>
#     <tr>
#       <td>0.133</td>
#       <td>Audio courtesy of c</td>
#     </tr>
#     <tr>
#       <td>0.095</td>
#       <td>n is is yet to officially declare himself a dictator and his proposed Religious Discrimination Laws are still to be passed. If he wins the next election .. troops in the streets, book burnings, compulsory weekly attendance at g and youth rallies?</td>
#     </tr>
#     <tr>
#       <td>0.067</td>
#       <td>But you’re arguments abt lesbians fall short. Due to the fact that they’re way too rigid &amp; You’re not the lesbian police. Sorry- if u want to argue you need better logical approaches (And possibly a wider grasp of subject)</td>
#     </tr>
#   </tbody>
# </table>
