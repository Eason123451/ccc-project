# %%
from get_tweets_sentiment_url import plot_combined_sentiment_and_tweets
from get_viccrime_sentiment_url import plot_crime_sentiment_url
from get_interesting_day_url import plot_sentiment_distribution, sample_crime_busiest_tweets, sample_crime_quietest_tweets

# %% [markdown]
# ### Scenario 1: Daily Sentiment and Tweet Volume Analysis

# %%
# Display the average sentiment of tweets and the number of tweets for each day
plot_combined_sentiment_and_tweets()

# %% [markdown]
# ### Scenario 2: Sentiment Distribution on Busiest and Quietest Days

# %%
# Display the distribution of sentiment on the busiest day and the quietest day
plot_sentiment_distribution()

# %% [markdown]
# ### Scenario 3: Correlation between Crime Reports and Sentiment

# %%
# Display the plot of correlation between crime reports and sentiment
plot_crime_sentiment_url()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ### Scenario 4: Sampling Crime-Related Tweets

# %%
# Every time you run this, you will get different crime-related tweets
sample_crime_busiest_tweets()
# Out:
#     <style>
#         table, th, td {
#             border: 1px solid black;
#             border-collapse: collapse;
#         }
#         th, td {
#             padding: 10px;
#             text-align: left;
#             vertical-align: top;
#         }
#         td {
#             max-width: 500px;  /* Adjust the width of the cells */
#             word-wrap: break-word;  /* Ensures that words wrap and text does not overflow */
#         }
#     </style>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Sentiment</th>
#       <th>Text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.235</td>
#       <td>V have a 7 day free trial. I binged o. It’s quite good</td>
#     </tr>
#     <tr>
#       <td>0.107</td>
#       <td>Geez I would have loved to have seen the continuation of that video, had the police officer snapped a baton right across the imbeciles back *CRACK!</td>
#     </tr>
#     <tr>
# ...

# %%
# Every time you run this, you will get different crime-related tweets
sample_crime_quietest_tweets()
# Out:
#     <style>
#         table, th, td {
#             border: 1px solid black;
#             border-collapse: collapse;
#         }
#         th, td {
#             padding: 10px;
#             text-align: left;
#             vertical-align: top;
#         }
#         td {
#             max-width: 500px;  /* Adjust the width of the cells */
#             word-wrap: break-word;  /* Ensures that words wrap and text does not overflow */
#         }
#     </style>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Sentiment</th>
#       <th>Text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.043</td>
#       <td>Debatable; the data isn't there yet. The fact that there are cheap, low toxicity, more effective early treatments that have been proven to work through intensive clinical trials renders the vaccine completely moot. But wait, they were shut down for political and monetary reasons.</td>
#     </tr>
#     <tr>
# ...
