# %%
from get_average_sentiment_url import plot_average_sentiment_url
from get_daily_tweets_url import plot_total_tweets_over_time_url

# %%
# Plot the average sentiment of tweets over time
plot_average_sentiment_url()

# %%
# Plot the total number of tweets over time
plot_total_tweets_over_time_url()
