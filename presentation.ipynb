# %%
from get_tweets_sentiment_url import plot_combined_sentiment_and_tweets
from get_viccrime_sentiment_url import plot_crime_sentiment_url
from get_interesting_day_url import plot_sentiment_distribution, sample_crime_busiest_tweets, sample_crime_quietest_tweets

# %% [markdown]
# ### Compare Average Sentiment Every Day with The Number of Tweets Every Day

# %%
plot_combined_sentiment_and_tweets()

# %%
plot_sentiment_distribution()

# %% [markdown]
# ### Correlation between Crime Reports and Daily Average Sentiment

# %%
plot_crime_sentiment_url()

# %% [markdown]
# ### Sample Crime Related Tweet for The Two Interesting Days

# %%
sample_crime_busiest_tweets()
# Out:
#     <style>
#         table, th, td {
#             border: 1px solid black;
#             border-collapse: collapse;
#         }
#         th, td {
#             padding: 10px;
#             text-align: left;
#             vertical-align: top;
#         }
#         td {
#             max-width: 500px;  /* Adjust the width of the cells */
#             word-wrap: break-word;  /* Ensures that words wrap and text does not overflow */
#         }
#     </style>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Sentiment</th>
#       <th>Text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>-0.182</td>
#       <td>LOCK THEM ALL UP NOW FOR ATTEMPTED MURDER!</td>
#     </tr>
#     <tr>
#       <td>0.059</td>
#       <td>Yeah, the fence sitters should watch the missiles thrown at Police, that’ll wake them up.</td>
#     </tr>
#     <tr>
#       <td>0.250</td>
#       <td>I’m watching it with my mother in law and we were laughing our heads off when we heard you  so good! Thanks for the entertainment..and the gym too</td>
#     </tr>
#     <tr>
#       <td>0.182</td>
#       <td>At last the courts got it right</td>
#     </tr>
#     <tr>
#       <td>-0.200</td>
#       <td>Give in to terrorists? Absolutely not.</td>
#     </tr>
#   </tbody>
# </table>

# %%
sample_crime_quietest_tweets()
# Out:
#     <style>
#         table, th, td {
#             border: 1px solid black;
#             border-collapse: collapse;
#         }
#         th, td {
#             padding: 10px;
#             text-align: left;
#             vertical-align: top;
#         }
#         td {
#             max-width: 500px;  /* Adjust the width of the cells */
#             word-wrap: break-word;  /* Ensures that words wrap and text does not overflow */
#         }
#     </style>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Sentiment</th>
#       <th>Text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.043</td>
#       <td>Debatable; the data isn't there yet. The fact that there are cheap, low toxicity, more effective early treatments that have been proven to work through intensive clinical trials renders the vaccine completely moot. But wait, they were shut down for political and monetary reasons.</td>
#     </tr>
#     <tr>
#       <td>-0.022</td>
#       <td>While I'm not as deep into Switch as you are, I suspect we could probably share a few stories over a brew or two. Switch stuff, along with the Vita games and consoles I forgot were in the attic, is all I have now.</td>
#     </tr>
#     <tr>
#       <td>0.056</td>
#       <td>s will take him They love props who get in trouble with the law</td>
#     </tr>
#     <tr>
#       <td>0.115</td>
#       <td>Interesting. I suspect that because I have blocked most politically-related names and terms, my \</td>
#     </tr>
#     <tr>
#       <td>-0.019</td>
#       <td>People please become familiar with the Biosecurity Act Section 60 and 61 as well as the Privacy Act 1988 94H as well as the n 51.23a . This is all you need to prove our governments both state and federal are relying on our ignorance with d law</td>
#     </tr>
#   </tbody>
# </table>
